# %%
a=int(input("enter a number"))
if(a%7==0):
    print("divisible by 7")
else:
    print("Not divisible by 7")
# Out:
# enter a number64
# Not divisible by 7

# %%
a=input("enter a word : ")
if(a=="a","e","i","o","u"):
    print("vowel")
else:
    print("consonent")
# Out:
# enter a word : I
# vowels

# %%
a=int(input("Enter your Age: "))
if(a>=18):
    print("eligible for applying for driving licence")
else:
    print("Not eligible")
# Out:
# Enter your Age: 25
# eligible for applying for driving licence

# %%
a=str(input("enter the first string: "))
b=str(input("enter the second string: "))
if(a==b):
    print("equal")
else:
    print("Not equal")
# Out:
# enter the first string: shradha
# enter the second string: shrfgha
# Not equal

# %%
a=int(input("enter the purchase amount: "))
if(a>5000):
    print("customer is eligible for discount")
else:
    print("Customer Not Eligible for discount")
# Out:
# enter the purchase amount: 5001
# customer is eligible for discount

# %%
a=int(input("enter the number: "))
if(a>=10 and a<=100):
    print("The number lies between  1and 100")
else:
    print("The number does not lie between 1-100")
# Out:
# enter the number: 101
# The number does not lie between 1-100

# %%
a=float(input("enter the attendence percentage: "))
if(a>=75):
    print("Eligible to Attend  Exam")
else:
    print("Not eligibel to attend exam")
# Out:
# enter the attendence percentage: 74.999
# Not eligibel to attend exam

# %%
a=input("enter the alphabet:  ")
if a>='A' and a<='Z':
    print("uppercase")
else:
    print("Lower")
# Out:
# enter the alphabet:  H
# uppercase

# %%
a=input("enter the alphabet:  ")
if 'A'<=a<='Z':
    print("uppercase")
else:
    print("Lower")
# Out:
# enter the alphabet:  F
# uppercase

# %%
a=int(input("enter the number: "))

if(a==3):
    print("Its a 3 digit Number")
else:
    print("Not a 3 digit number")

# %%
a=float(input("enter  the amt of mobile data used in GB: "))
if(a<2):
    print("Low Usage")
elif a>=2 and a<=5:
    print("Moderate Usage")
else:
    print("High Usage")
# Out:
# enter  the amt of mobile data used in GB: 2.87
# Moderate Usage
