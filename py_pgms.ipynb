# %%
a=int(input("Enter 1st number:"))
b=int(input("enter 2nd number:"))
c=a+b
d=a-b
e=a*b
f=a/b
g=a%b
print("ADDITION:",c)
print("subtraction:",d)
print("product:",e)
print("division:",f)
print("Reminder:",g)
# Out:
# Enter 1st number:100
# enter 2nd number:5
# ADDITION: 105
# subtraction: 95
# product: 500
# division: 20.0
# Reminder: 0

# %%
a=int(input("Enter 1st number:"))
b=int(input("enter 2nd number:"))
c=a/b
d=a%b
print("Quotient:",c)
print("Reminder:",d)
# Out:
# Enter 1st number:50
# enter 2nd number:2
# Quotient: 25.0
# Reminder: 0

# %%
r=int(input("Enter the radius of the circle:"))
area=3.14*r*r
print("Area of the circle:",area)
# Out:
# Enter the radius of the circle:5
# Area of the circle: 78.5

# %%
a=int(input("Enter 1st number:"))
b=int(input("enter 2nd number:"))
c=int(input("enter 3rd number:"))
d=(a+b+c)/3
print("Average of 3 : ",d)
# Out:
# Enter 1st number:2
# enter 2nd number:5
# enter 3rd number:8
# Average of 3 :  5.0

# %%
c=int(input("Enter the temperature in celsius:"))
f=(c*1.8)+32
print("faherenheit: ",f)
# Out:
# Enter the temperature in celsius:20
# faherenheit:  68.0

# %%
a=int(input("Enter 1st side :"))
b=int(input("enter 2nd side :"))

area=a*b
print("area of sq: ",area)
# Out:
# Enter 1st side :5
# enter 2nd side :5
# area of sq:  25

# %%
a=int(input("Enter base :"))
b=int(input("enter height :"))
area=(a*b)/2
print("area: ",area)
# Out:
# Enter base :4
# enter height :2
# area:  4.0

# %%
a=int(input("Enter the principle amt :"))
b=int(input("enter the rate of interest :"))
c=int(input("enter the time/duratioon :"))
si=(a*b*c)/100
print("Simplpe Interest : ",si)
# Out:
# Enter the principle amt :25000
# enter the rate of interest :10
# enter the time/duratioon :2
# Simplpe Interest :  5000.0

# %%
a=int(input("Enter the number :"))
p=a-1
n=a+1
print("previous number:",p)
print("previous number:",n)
# Out:
# Enter the number :5
# previous number: 4
# previous number: 6
